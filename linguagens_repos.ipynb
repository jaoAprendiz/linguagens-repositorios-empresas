# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"47346963981","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":668978672,"name":"weiyan456/weiyan4","url":"https://api.github.com/repos/weiyan456/weiyan4"},"payload":{"repository_id":668978672,"push_id":23061345748,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"4a9ed29d5439a5840b948af151e98cb270727a4d","before":"46590ac8405cef377e43576c0e8776152c421c17","commits":[{"sha":"4a9ed29d5439a5840b948af151e98cb270727a4d","author":{"email":"liyiwo10@163.com","name":"weiyan456"},"message":"a commit a day keeps your girlfriend away","distinct":true,"url":"https://api.github.com/repos/weiyan456/weiyan4/commits/4a9ed29d5439a5840b948af151e98cb270727a4d"}]},"public":true,"created_at":"2025-03-08T22:55:07Z"},{"id":"47346963982","type":"PushEvent","actor":{"id":184176187,"login":"Reiii3","display_login":"Reiii3","gravatar_id":"","url":"https://api.github.com/users/Reiii3","avatar_url":"https://avatars.githubusercontent.com/u/184176187?"},"repo":{"id":909416178,"name":"Reiii3/Center-Module","url":"https://api.github.com/repos/Reiii3/Center-Module"},"payload":{"repository_id":909416178,"push_id":23061345766,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"41da59ff78d0950c1e6141fee80fc33a4349deed","before":"a6a8bf8c2c962fc88fecf978a83813118425008f","commits":[{"sha":"41da59ff78d0950c1e6141fee80fc33a4349deed","author":{"email":"mohtoyib79@gmail.com","name":"Reiii3"},"message":"update bin/tes_cekgame.sh","distinct":true,"url":"https://api.github.com/repos/Reiii3/Center-Module/commits/41da59ff78d0950c1e6141fee80fc33a4349deed"}]},"public":true,"created_at":"2025-03-08T22:55:07Z"},{"id":"47346963989","type":"CreateEvent","actor":{"id":22369562,"login":"saurabharch","display_login":"saurabharch","gravatar_id":"","url":"https://api.github.com/users/saurabharch","avatar_url":"https://avatars.githubusercontent.com/u/22369562?"},"repo":{"id":130582730,"name":"saurabharch/chat-engine","url":"https://api.github.com/repos/saurabharch/chat-engine"},"payload":{"ref":"snyk-fix-b02f9e1ef1e9203fcffec788bb6d593b","ref_type":"branch","master_branch":"master","description":"Object oriented event emitter based framework for building chat applications in Javascript.","pusher_type":"user"},"public":true,"created_at":"2025-03-08T22:55:07Z"},{"id":"47346963979","type":"PushEvent","actor":{"id":6697380,"login":"Sewer56","display_login":"Sewer56","gravatar_id":"","url":"https://api.github.com/users/Sewer56","avatar_url":"https://avatars.githubusercontent.com/u/6697380?"},"repo":{"id":523151182,"name":"Reloaded-Project/Reloaded-II.Index","url":"https://api.github.com/repos/Reloaded-Project/Reloaded-II.Index"},"payload":{"repository_id":523151182,"push_id":23061345753,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"19aebdbcfdb006d056a7b391f22655019a78289d","before":"ef3e63f4648e2d19ddd0c582c03f589c67db1098","commits":[{"sha":"19aebdbcfdb006d056a7b391f22655019a78289d","author":{"email":"admin@sewer56.dev","name":"Reloaded Index Bot"},"message":"[Bot] Updated: Persona 5 Royal (GameBanana)","distinct":true,"url":"https://api.github.com/repos/Reloaded-Project/Reloaded-II.Index/commits/19aebdbcfdb006d056a7b391f22655019a78289d"}]},"public":true,"created_at":"2025-03-08T22:55:07Z","org":{"id":45473408,"login":"Reloaded-Project","gravatar_id":"","url":"https://api.github.com/orgs/Reloaded-Project","avatar_url":"https://avatars.githubusercontent.com/u/45473408?"}},{"id":"47346963977","type":"CreateEvent","actor":{"id":183291069,"login":"Kleb-0","display_login":"Kleb-0","gravatar_id":"","url":"https://api.github.com/users/Kleb-0","avatar_url":"https://avatars.githubusercontent.com/u/183291069?"},"repo":{"id":945211440,"name":"Kleb-0/Portifolio","url":"https://api.github.com/repos/Kleb-0/Portifolio"},"payload":{"ref":null,"ref_type":"reposit ...

# %%
r.json()
# Out:
# [{'id': '47346963981',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 668978672,
#    'name': 'weiyan456/weiyan4',
#    'url': 'https://api.github.com/repos/weiyan456/weiyan4'},
#   'payload': {'repository_id': 668978672,
#    'push_id': 23061345748,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4a9ed29d5439a5840b948af151e98cb270727a4d',
#    'before': '46590ac8405cef377e43576c0e8776152c421c17',
#    'commits': [{'sha': '4a9ed29d5439a5840b948af151e98cb270727a4d',
#      'author': {'email': 'liyiwo10@163.com', 'name': 'weiyan456'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/weiyan456/weiyan4/commits/4a9ed29d5439a5840b948af151e98cb270727a4d'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963982',
#   'type': 'PushEvent',
#   'actor': {'id': 184176187,
#    'login': 'Reiii3',
#    'display_login': 'Reiii3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Reiii3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/184176187?'},
#   'repo': {'id': 909416178,
#    'name': 'Reiii3/Center-Module',
#    'url': 'https://api.github.com/repos/Reiii3/Center-Module'},
#   'payload': {'repository_id': 909416178,
#    'push_id': 23061345766,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '41da59ff78d0950c1e6141fee80fc33a4349deed',
#    'before': 'a6a8bf8c2c962fc88fecf978a83813118425008f',
#    'commits': [{'sha': '41da59ff78d0950c1e6141fee80fc33a4349deed',
#      'author': {'email': 'mohtoyib79@gmail.com', 'name': 'Reiii3'},
#      'message': 'update bin/tes_cekgame.sh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Reiii3/Center-Module/commits/41da59ff78d0950c1e6141fee80fc33a4349deed'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963989',
#   'type': 'CreateEvent',
#   'actor': {'id': 22369562,
#    'login': 'saurabharch',
#    'display_login': 'saurabharch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saurabharch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22369562?'},
#   'repo': {'id': 130582730,
#    'name': 'saurabharch/chat-engine',
#    'url': 'https://api.github.com/repos/saurabharch/chat-engine'},
#   'payload': {'ref': 'snyk-fix-b02f9e1ef1e9203fcffec788bb6d593b',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Object oriented event emitter based framework for building chat applications in Javascript.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963979',
#   'type': 'PushEvent',
#   'actor': {'id': 6697380,
#    'login': 'Sewer56',
#    'display_login': 'Sewer56',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sewer56',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6697380?'},
#   'repo': {'id': 523151182,
#    'name': 'Reloaded-Project/Reloaded-II.Index',
#    'url': 'https://api.github.com/repos/Reloaded-Project/Reloaded-II.Index'},
#   'payload': {'repository_id': 523151182,
#    'push_id': 23061345753,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '19aebdbcfdb006d056a7b391f22655019a78289d',
#    'before': 'ef3e63f4648e2d19ddd0c582c03f589c67db1098',
#    'commits': [{'sha': '19aebdbcfdb006d056a7b391f22655019a78289d',
#      'author': {'email': 'admin@sewer56.dev', 'name': 'Reloaded Index Bot'},
#      'message': '[Bot] Updated: Persona 5 Royal (GameBanana)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Reloaded-Project/Reloaded-II.Index/commits/19aebdbcfdb006d056a7b391f22655019a78289d'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 45473408,
#    'login': 'Reloaded-Project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Reloaded-Project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45473408?'}},
#  {'id': '47346963977',
#   'type': 'CreateEvent',
#   'actor': {'id': 183291069,
#    'login': 'Kleb-0',
#    'display_login': 'Kleb-0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kleb-0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/183291069?'},
#   'repo': {'id': 945211440,
#    'name': 'Kleb-0/Portifolio',
#    'url': 'https://api.github.com/repos/Kleb-0/Portifolio'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Welcome to my personal portifolio, where i showcase my main projects and share a bit about myself.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963972',
#   'type': 'PushEvent',
#   'actor': {'id': 65356582,
#    'login': 'stukusva',
#    'display_login': 'stukusva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stukusva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65356582?'},
#   'repo': {'id': 480796774,
#    'name': 'StukFi/stukfi.github.io',
#    'url': 'https://api.github.com/repos/StukFi/stukfi.github.io'},
#   'payload': {'repository_id': 480796774,
#    'push_id': 23061345745,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2f536739050b5b1adff11fc4431be4e52517cdde',
#    'before': '17fc8963d63760b11fa5a1443cedd31d5929e8e7',
#    'commits': [{'sha': '2f536739050b5b1adff11fc4431be4e52517cdde',
#      'author': {'email': 'usva.stuk@gmail.com', 'name': 'stukusva'},
#      'message': 'update latest data programmatically',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StukFi/stukfi.github.io/commits/2f536739050b5b1adff11fc4431be4e52517cdde'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 44080343,
#    'login': 'StukFi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/StukFi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44080343?'}},
#  {'id': '47346963966',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 892248417,
#    'name': 'Check-W/Autowithdraw',
#    'url': 'https://api.github.com/repos/Check-W/Autowithdraw'},
#   'payload': {'repository_id': 892248417,
#    'push_id': 23061345765,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5c2945abbef681f71660cb421192ebd0d06c8a39',
#    'before': '547605c45a8d0ac478790030cc6565e8136d708d',
#    'commits': [{'sha': '5c2945abbef681f71660cb421192ebd0d06c8a39',
#      'author': {'email': 'ischhfd83@rambler.ru', 'name': 'Check-W'},
#      'message': 'Auto Withdraw',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Check-W/Autowithdraw/commits/5c2945abbef681f71660cb421192ebd0d06c8a39'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 189281346,
#    'login': 'Check-W',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Check-W',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/189281346?'}},
#  {'id': '47346963960',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 457536633,
#    'name': 'WhitehawkCEC/statuspage',
#    'url': 'https://api.github.com/repos/WhitehawkCEC/statuspage'},
#   'payload': {'repository_id': 457536633,
#    'push_id': 23061345763,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '99980173c9c932322c939f5a5da4a3c90c2eaac1',
#    'before': '7bf910458b682356f449ba740ce475e996da9597',
#    'commits': [{'sha': '99980173c9c932322c939f5a5da4a3c90c2eaac1',
#      'author': {'email': 'whdevops@whitehawk.com', 'name': 'Whitehawk DevOps'},
#      'message': '[Automated] Update Health Check Logs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/WhitehawkCEC/statuspage/commits/99980173c9c932322c939f5a5da4a3c90c2eaac1'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 25796117,
#    'login': 'WhitehawkCEC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WhitehawkCEC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25796117?'}},
#  {'id': '47346963956',
#   'type': 'PushEvent',
#   'actor': {'id': 182483123,
#    'login': 'freefastconnect',
#    'display_login': 'freefastconnect',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freefastconnect',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/182483123?'},
#   'repo': {'id': 861597434,
#    'name': 'freefastconnect/fastconnect',
#    'url': 'https://api.github.com/repos/freefastconnect/fastconnect'},
#   'payload': {'repository_id': 861597434,
#    'push_id': 23061345770,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '42666ec875145b0f709ede9c41ae8903443bfcbe',
#    'before': '2512d8ee2d77b134b5483cdfc9408939f8f70194',
#    'commits': [{'sha': '42666ec875145b0f709ede9c41ae8903443bfcbe',
#      'author': {'email': 'freefastconnect@gmail.com',
#       'name': 'freefastconnect'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freefastconnect/fastconnect/commits/42666ec875145b0f709ede9c41ae8903443bfcbe'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963962',
#   'type': 'CreateEvent',
#   'actor': {'id': 174311533,
#    'login': 'demoncoder-crypto',
#    'display_login': 'demoncoder-crypto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/demoncoder-crypto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/174311533?'},
#   'repo': {'id': 944855843,
#    'name': 'demoncoder-crypto/generative-ai-js',
#    'url': 'https://api.github.com/repos/demoncoder-crypto/generative-ai-js'},
#   'payload': {'ref': 'feature/stream-callbacks',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'The official Node.js / Typescript library for the Google Gemini API',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963958',
#   'type': 'WatchEvent',
#   'actor': {'id': 198357481,
#    'login': '906335',
#    'display_login': '906335',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/906335',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/198357481?'},
#   'repo': {'id': 943398999,
#    'name': 'x1xhlol/system-prompts-and-models-of-ai-tools',
#    'url': 'https://api.github.com/repos/x1xhlol/system-prompts-and-models-of-ai-tools'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963953',
#   'type': 'CreateEvent',
#   'actor': {'id': 166895733,
#    'login': 'swa-runner-app[bot]',
#    'display_login': 'swa-runner-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'},
#   'repo': {'id': 945211436,
#    'name': 'static-web-apps-testing-org/swa63507c7f16024cfc8e0d0519cfe6bd11',
#    'url': 'https://api.github.com/repos/static-web-apps-testing-org/swa63507c7f16024cfc8e0d0519cfe6bd11'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'swa63507c7f16024cfc8e0d0519cfe6bd11',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 96167003,
#    'login': 'static-web-apps-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/static-web-apps-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}},
#  {'id': '47346963950',
#   'type': 'PushEvent',
#   'actor': {'id': 202432146,
#    'login': 'Endroye',
#    'display_login': 'Endroye',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Endroye',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/202432146?'},
#   'repo': {'id': 945081676,
#    'name': 'Endroye/canyoubeattheboss',
#    'url': 'https://api.github.com/repos/Endroye/canyoubeattheboss'},
#   'payload': {'repository_id': 945081676,
#    'push_id': 23061345768,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '327e3426933eae395653311d253b5808abfa3c8f',
#    'before': 'd0088873815a58cf3d313040bb5030dd8c8e4432',
#    'commits': [{'sha': '327e3426933eae395653311d253b5808abfa3c8f',
#      'author': {'email': 'Endroye@blue-liveconsole11', 'name': 'Endroye'},
#      'message': 'Overlay-Daten aktualisiert',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Endroye/canyoubeattheboss/commits/327e3426933eae395653311d253b5808abfa3c8f'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963954',
#   'type': 'CreateEvent',
#   'actor': {'id': 108541612,
#    'login': 'PlanetLumi',
#    'display_login': 'PlanetLumi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PlanetLumi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108541612?'},
#   'repo': {'id': 930900928,
#    'name': '7ouless/apocRogue',
#    'url': 'https://api.github.com/repos/7ouless/apocRogue'},
#   'payload': {'ref': 'game-logic-integration-test',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963948',
#   'type': 'PushEvent',
#   'actor': {'id': 173535095,
#    'login': 'frdpzk2',
#    'display_login': 'frdpzk2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frdpzk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/173535095?'},
#   'repo': {'id': 818567109,
#    'name': 'frdpzk2/ppub',
#    'url': 'https://api.github.com/repos/frdpzk2/ppub'},
#   'payload': {'repository_id': 818567109,
#    'push_id': 23061345744,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e33c749e3b3f1becf7441dbef647c5724b60cba0',
#    'before': 'baf63b391cf63a2bc811565c7326650239bd3fc6',
#    'commits': [{'sha': 'e33c749e3b3f1becf7441dbef647c5724b60cba0',
#      'author': {'email': 'frdpzk2@gmail.com', 'name': 'frdpzk2'},
#      'message': 'commited',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/frdpzk2/ppub/commits/e33c749e3b3f1becf7441dbef647c5724b60cba0'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963943',
#   'type': 'PushEvent',
#   'actor': {'id': 29929185,
#    'login': 'stevenwhayes',
#    'display_login': 'stevenwhayes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stevenwhayes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29929185?'},
#   'repo': {'id': 924842733,
#    'name': 'sweatycomputing/sglogs',
#    'url': 'https://api.github.com/repos/sweatycomputing/sglogs'},
#   'payload': {'repository_id': 924842733,
#    'push_id': 23061345756,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '920c693aee071ed719636801b57536f283b9b8b3',
#    'before': '1d73af09d50ceb571387f887f123109cb1e61cb2',
#    'commits': [{'sha': '920c693aee071ed719636801b57536f283b9b8b3',
#      'author': {'email': 'no-reply@example.com', 'name': 'Anonymous User'},
#      'message': 'Update log view on Sat Mar  8 10:55:01 PM UTC 2025',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sweatycomputing/sglogs/commits/920c693aee071ed719636801b57536f283b9b8b3'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z',
#   'org': {'id': 176528353,
#    'login': 'sweatycomputing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sweatycomputing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/176528353?'}},
#  {'id': '47346963944',
#   'type': 'PushEvent',
#   'actor': {'id': 171124844,
#    'login': 'freeukapp',
#    'display_login': 'freeukapp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freeukapp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/171124844?'},
#   'repo': {'id': 887068329,
#    'name': 'freeukapp/uk',
#    'url': 'https://api.github.com/repos/freeukapp/uk'},
#   'payload': {'repository_id': 887068329,
#    'push_id': 23061345743,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1f9cccee3a09603963b75f9c34e9e969372b57ce',
#    'before': '4896a746d97c7b71f0793d7c0c971f18fb30a993',
#    'commits': [{'sha': '1f9cccee3a09603963b75f9c34e9e969372b57ce',
#      'author': {'email': 'appadlou@gmail.com', 'name': 'freeukapp'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freeukapp/uk/commits/1f9cccee3a09603963b75f9c34e9e969372b57ce'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963940',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 21371374,
#    'login': 'morguldir',
#    'display_login': 'morguldir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/morguldir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21371374?'},
#   'repo': {'id': 723770769,
#    'name': 'girlbossceo/conduwuit',
#    'url': 'https://api.github.com/repos/girlbossceo/conduwuit'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699',
#     'repository_url': 'https://api.github.com/repos/girlbossceo/conduwuit',
#     'labels_url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699/comments',
#     'events_url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699/events',
#     'html_url': 'https://github.com/girlbossceo/conduwuit/issues/699',
#     'id': 2904741552,
#     'node_id': 'I_kwDOKyPdkc6tItaw',
#     'number': 699,
#     'title': 'database corrupted by external process - conduit_core::error: State hash does not exist',
#     'user': {'login': 'lafleurdeboum',
#      'id': 35574148,
#      'node_id': 'MDQ6VXNlcjM1NTc0MTQ4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/35574148?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lafleurdeboum',
#      'html_url': 'https://github.com/lafleurdeboum',
#      'followers_url': 'https://api.github.com/users/lafleurdeboum/followers',
#      'following_url': 'https://api.github.com/users/lafleurdeboum/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lafleurdeboum/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lafleurdeboum/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lafleurdeboum/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lafleurdeboum/orgs',
#      'repos_url': 'https://api.github.com/users/lafleurdeboum/repos',
#      'events_url': 'https://api.github.com/users/lafleurdeboum/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lafleurdeboum/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2025-03-08T11:48:08Z',
#     'updated_at': '2025-03-08T22:55:06Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'body': 'The server booted the wrong kernel, and scrambled the eMMC storage. I recovered most data with `ddrescue`, but there are many binary read errors all over data.\n\nI rebooted Archlinux\'s conduwuit 0.4.6 with this config (I redacted the URL and the registration token). The server has nginx proxying requests to example.com to localhost:6167. It\'s the setup it used to work with.\n\nI read in #683 that the option `rocksdb_recovery_mode=2` would help recovery.\n```\n[global]\nrocksdb_repair = true\nrocksdb_recovery_mode = 2\ndatabase_backup_path = "/var/lib/conduit-backup/"\nallow_registration = true\nregistration_token="redacted token"\nserver_name = "example.com"\ndatabase_path = "/var/lib/conduit/"\ndatabase_backend = "rocksdb"\nallow_federation = true\nlog = "info"\naddress = "127.0.0.1"\nport = 6167\n\nturn_uris = ["turn:example.com?transport=udp", "turn:example.com?transport=tcp"]\nturn_secret = "de_la_haut_je_vois_ma_maison"\n\n[global.well_known]\nserver = "example.com:443"\nclient = "https://example.com"\n```\nThe recovery reportedly worked. But when a user tries to use their client - here @lafleur:example.com with Element - I get the following logs in conduwuit : \n```\n2025-03-08T11:22:47.079157Z ERROR router:{path=/_matrix/client/v3/sync}:handle: conduit_api::client::sync: Pdu in state not found: $pDU24BDIWZd_nn_Eimjk20wlzvJIkYz8hp6ztDLkN_8\n2025-03-08T11:22:47.147004Z ERROR router:{path=/_matrix/client/v3/sync}:handle: conduit_core::error: State hash does not exist\n2025-03-08T11:22:47.406906Z ERROR router:{path=/_matrix/client/v3/sync}:handle:left_room{user_id=@lafleur:example.com room_id=!9vd7iMF719UcyF4C4d:example.com}: conduit_core::error: State hash does not exist\n2025-03-08T11:22:47.408060Z ERROR router:{path=/_matrix/client/v3/sync}:handle: conduit_router::request: 500 Internal Server Error method=GET uri=/_matrix/client/v3/sync?filter=%7B%22room%22%3A%7B%22include_leave%22%3Atrue%2C%22state%22%3A%7B%22lazy_load_members%22%3Atrue%7D%7D%7D&timeout=30000\n2025-03-08T11:22:47.408211Z ERROR router:{path=/_matrix/client/v3/sync}: tower_http::trace::on_failure: response failed classification=Status code: 500 Internal Server Error latency=2367 ms\n```\nI uploaded a pastebin of the whole conduwuit session with a lovely url : [https://termbin.com/lovz](https://termbin.com/lovz).\n\nI wish I could recover the user\'s metadatas, and all possible messages, but now clients fail to sync and stay stuck in "initial sync: waiting for server" state (I tried element-android, element-desktop and fractal).',
#     'reactions': {'url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/comments/2708522610',
#     'html_url': 'https://github.com/girlbossceo/conduwuit/issues/699#issuecomment-2708522610',
#     'issue_url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/699',
#     'id': 2708522610,
#     'node_id': 'IC_kwDOKyPdkc6hcMZy',
#     'user': {'login': 'morguldir',
#      'id': 21371374,
#      'node_id': 'MDQ6VXNlcjIxMzcxMzc0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/21371374?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/morguldir',
#      'html_url': 'https://github.com/morguldir',
#      'followers_url': 'https://api.github.com/users/morguldir/followers',
#      'following_url': 'https://api.github.com/users/morguldir/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/morguldir/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/morguldir/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/morguldir/subscriptions',
#      'organizations_url': 'https://api.github.com/users/morguldir/orgs',
#      'repos_url': 'https://api.github.com/users/morguldir/repos',
#      'events_url': 'https://api.github.com/users/morguldir/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/morguldir/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-03-08T22:55:06Z',
#     'updated_at': '2025-03-08T22:55:06Z',
#     'author_association': 'COLLABORATOR',
#     'body': "also since it's a left room you could try calling /forget with curl https://spec.matrix.org/v1.13/client-server-api/#post_matrixclientv3roomsroomidforget",
#     'reactions': {'url': 'https://api.github.com/repos/girlbossceo/conduwuit/issues/comments/2708522610/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963936',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 754922982,
#    'name': 'A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List',
#    'url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List'},
#   'payload': {'action': 'closed',
#    'number': 278,
#    'pull_request': {'url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278',
#     'id': 2380397413,
#     'node_id': 'PR_kwDOLP815s6N4ftl',
#     'html_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278',
#     'diff_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278.diff',
#     'patch_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278.patch',
#     'issue_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/278',
#     'number': 278,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] master from Tzwcard:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'See [Commits](/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278/commits) and [Changes](/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull) (v2.0.0-alpha.1)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2025-03-08T22:55:03Z',
#     'updated_at': '2025-03-08T22:55:06Z',
#     'closed_at': '2025-03-08T22:55:06Z',
#     'merged_at': '2025-03-08T22:55:06Z',
#     'merge_commit_sha': 'c9cbef1ae32efc85508f4ff5a026f06686f68ba2',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 6540527379,
#       'node_id': 'LA_kwDOLP815s8AAAABhdiHEw',
#       'url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278/commits',
#     'review_comments_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278/comments',
#     'review_comment_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/278/comments',
#     'statuses_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/statuses/c9cbef1ae32efc85508f4ff5a026f06686f68ba2',
#     'head': {'label': 'Tzwcard:master',
#      'ref': 'master',
#      'sha': 'c9cbef1ae32efc85508f4ff5a026f06686f68ba2',
#      'user': {'login': 'Tzwcard',
#       'id': 12098388,
#       'node_id': 'MDQ6VXNlcjEyMDk4Mzg4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12098388?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Tzwcard',
#       'html_url': 'https://github.com/Tzwcard',
#       'followers_url': 'https://api.github.com/users/Tzwcard/followers',
#       'following_url': 'https://api.github.com/users/Tzwcard/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Tzwcard/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Tzwcard/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Tzwcard/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Tzwcard/orgs',
#       'repos_url': 'https://api.github.com/users/Tzwcard/repos',
#       'events_url': 'https://api.github.com/users/Tzwcard/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Tzwcard/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 229153710,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjkxNTM3MTA=',
#       'name': 'ChinaTelecom-GuangdongIPTV-RTP-List',
#       'full_name': 'Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'private': False,
#       'owner': {'login': 'Tzwcard',
#        'id': 12098388,
#        'node_id': 'MDQ6VXNlcjEyMDk4Mzg4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12098388?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Tzwcard',
#        'html_url': 'https://github.com/Tzwcard',
#        'followers_url': 'https://api.github.com/users/Tzwcard/followers',
#        'following_url': 'https://api.github.com/users/Tzwcard/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Tzwcard/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Tzwcard/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Tzwcard/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Tzwcard/orgs',
#        'repos_url': 'https://api.github.com/users/Tzwcard/repos',
#        'events_url': 'https://api.github.com/users/Tzwcard/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Tzwcard/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'description': '广州电信广东IPTV列表（IGMP/RTP组播地址）',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'forks_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/forks',
#       'keys_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/teams',
#       'hooks_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/events',
#       'assignees_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/tags',
#       'blobs_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/languages',
#       'stargazers_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/subscription',
#       'commits_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/merges',
#       'archive_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/downloads',
#       'issues_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List/deployments',
#       'created_at': '2019-12-19T23:14:42Z',
#       'updated_at': '2025-03-08T21:23:32Z',
#       'pushed_at': '2025-03-08T21:23:28Z',
#       'git_url': 'git://github.com/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'ssh_url': 'git@github.com:Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'clone_url': 'https://github.com/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'svn_url': 'https://github.com/Tzwcard/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'homepage': '',
#       'size': 151807,
#       'stargazers_count': 835,
#       'watchers_count': 835,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 174,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 22,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 174,
#       'open_issues': 22,
#       'watchers': 835,
#       'default_branch': 'master'}},
#     'base': {'label': 'A-SunsetMkt-Forks:master',
#      'ref': 'master',
#      'sha': '6373934d4fdbe4bdf7b203abe92bc76e38a2b6f1',
#      'user': {'login': 'A-SunsetMkt-Forks',
#       'id': 182186282,
#       'node_id': 'O_kgDOCtvxKg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/182186282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/A-SunsetMkt-Forks',
#       'html_url': 'https://github.com/A-SunsetMkt-Forks',
#       'followers_url': 'https://api.github.com/users/A-SunsetMkt-Forks/followers',
#       'following_url': 'https://api.github.com/users/A-SunsetMkt-Forks/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/A-SunsetMkt-Forks/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/A-SunsetMkt-Forks/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/A-SunsetMkt-Forks/subscriptions',
#       'organizations_url': 'https://api.github.com/users/A-SunsetMkt-Forks/orgs',
#       'repos_url': 'https://api.github.com/users/A-SunsetMkt-Forks/repos',
#       'events_url': 'https://api.github.com/users/A-SunsetMkt-Forks/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/A-SunsetMkt-Forks/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 754922982,
#       'node_id': 'R_kgDOLP815g',
#       'name': 'ChinaTelecom-GuangdongIPTV-RTP-List',
#       'full_name': 'A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'private': False,
#       'owner': {'login': 'A-SunsetMkt-Forks',
#        'id': 182186282,
#        'node_id': 'O_kgDOCtvxKg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/182186282?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/A-SunsetMkt-Forks',
#        'html_url': 'https://github.com/A-SunsetMkt-Forks',
#        'followers_url': 'https://api.github.com/users/A-SunsetMkt-Forks/followers',
#        'following_url': 'https://api.github.com/users/A-SunsetMkt-Forks/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/A-SunsetMkt-Forks/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/A-SunsetMkt-Forks/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/A-SunsetMkt-Forks/subscriptions',
#        'organizations_url': 'https://api.github.com/users/A-SunsetMkt-Forks/orgs',
#        'repos_url': 'https://api.github.com/users/A-SunsetMkt-Forks/repos',
#        'events_url': 'https://api.github.com/users/A-SunsetMkt-Forks/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/A-SunsetMkt-Forks/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'description': '广州电信广东IPTV列表（IGMP/RTP组播地址）',
#       'fork': True,
#       'url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'forks_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/forks',
#       'keys_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/teams',
#       'hooks_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/hooks',
#       'issue_events_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/events',
#       'assignees_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/tags',
#       'blobs_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/languages',
#       'stargazers_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/stargazers',
#       'contributors_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/contributors',
#       'subscribers_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/subscribers',
#       'subscription_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/subscription',
#       'commits_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/merges',
#       'archive_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/downloads',
#       'issues_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/deployments',
#       'created_at': '2024-02-09T03:00:52Z',
#       'updated_at': '2025-03-07T22:55:10Z',
#       'pushed_at': '2025-03-08T22:55:05Z',
#       'git_url': 'git://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'ssh_url': 'git@github.com:A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'clone_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List.git',
#       'svn_url': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List',
#       'homepage': '',
#       'size': 151744,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278'},
#      'html': {'href': 'https://github.com/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pull/278'},
#      'issue': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/278'},
#      'comments': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/issues/278/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/pulls/278/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/A-SunsetMkt-Forks/ChinaTelecom-GuangdongIPTV-RTP-List/statuses/c9cbef1ae32efc85508f4ff5a026f06686f68ba2'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
# ...
#        'following_url': 'https://api.github.com/users/GNOME/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GNOME/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GNOME/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GNOME/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GNOME/orgs',
#        'repos_url': 'https://api.github.com/users/GNOME/repos',
#        'events_url': 'https://api.github.com/users/GNOME/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GNOME/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/GNOME/gtk',
#       'description': 'Read-only mirror of https://gitlab.gnome.org/GNOME/gtk',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GNOME/gtk',
#       'forks_url': 'https://api.github.com/repos/GNOME/gtk/forks',
#       'keys_url': 'https://api.github.com/repos/GNOME/gtk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GNOME/gtk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GNOME/gtk/teams',
#       'hooks_url': 'https://api.github.com/repos/GNOME/gtk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GNOME/gtk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GNOME/gtk/events',
#       'assignees_url': 'https://api.github.com/repos/GNOME/gtk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GNOME/gtk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GNOME/gtk/tags',
#       'blobs_url': 'https://api.github.com/repos/GNOME/gtk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GNOME/gtk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GNOME/gtk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GNOME/gtk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GNOME/gtk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GNOME/gtk/languages',
#       'stargazers_url': 'https://api.github.com/repos/GNOME/gtk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GNOME/gtk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GNOME/gtk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GNOME/gtk/subscription',
#       'commits_url': 'https://api.github.com/repos/GNOME/gtk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GNOME/gtk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GNOME/gtk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GNOME/gtk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GNOME/gtk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GNOME/gtk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GNOME/gtk/merges',
#       'archive_url': 'https://api.github.com/repos/GNOME/gtk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GNOME/gtk/downloads',
#       'issues_url': 'https://api.github.com/repos/GNOME/gtk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GNOME/gtk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GNOME/gtk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GNOME/gtk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GNOME/gtk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GNOME/gtk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GNOME/gtk/deployments',
#       'created_at': '2012-06-03T13:03:40Z',
#       'updated_at': '2025-03-08T20:11:24Z',
#       'pushed_at': '2025-03-08T20:11:19Z',
#       'git_url': 'git://github.com/GNOME/gtk.git',
#       'ssh_url': 'git@github.com:GNOME/gtk.git',
#       'clone_url': 'https://github.com/GNOME/gtk.git',
#       'svn_url': 'https://github.com/GNOME/gtk',
#       'homepage': 'https://gitlab.gnome.org/GNOME/gtk',
#       'size': 733056,
#       'stargazers_count': 1495,
#       'watchers_count': 1495,
#       'language': 'C',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 383,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 383,
#       'open_issues': 0,
#       'watchers': 1495,
#       'default_branch': 'main'}},
#     'base': {'label': 'kkpan11:main',
#      'ref': 'main',
#      'sha': 'a80b6917afb60d3afff945bf23e9771e29018e5d',
#      'user': {'login': 'kkpan11',
#       'id': 3894279,
#       'node_id': 'MDQ6VXNlcjM4OTQyNzk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3894279?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kkpan11',
#       'html_url': 'https://github.com/kkpan11',
#       'followers_url': 'https://api.github.com/users/kkpan11/followers',
#       'following_url': 'https://api.github.com/users/kkpan11/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kkpan11/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kkpan11/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kkpan11/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kkpan11/orgs',
#       'repos_url': 'https://api.github.com/users/kkpan11/repos',
#       'events_url': 'https://api.github.com/users/kkpan11/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kkpan11/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 673300429,
#       'node_id': 'R_kgDOKCG_zQ',
#       'name': 'gtk',
#       'full_name': 'kkpan11/gtk',
#       'private': False,
#       'owner': {'login': 'kkpan11',
#        'id': 3894279,
#        'node_id': 'MDQ6VXNlcjM4OTQyNzk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/3894279?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kkpan11',
#        'html_url': 'https://github.com/kkpan11',
#        'followers_url': 'https://api.github.com/users/kkpan11/followers',
#        'following_url': 'https://api.github.com/users/kkpan11/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kkpan11/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kkpan11/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kkpan11/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kkpan11/orgs',
#        'repos_url': 'https://api.github.com/users/kkpan11/repos',
#        'events_url': 'https://api.github.com/users/kkpan11/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kkpan11/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/kkpan11/gtk',
#       'description': 'Read-only mirror of https://gitlab.gnome.org/GNOME/gtk',
#       'fork': True,
#       'url': 'https://api.github.com/repos/kkpan11/gtk',
#       'forks_url': 'https://api.github.com/repos/kkpan11/gtk/forks',
#       'keys_url': 'https://api.github.com/repos/kkpan11/gtk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kkpan11/gtk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kkpan11/gtk/teams',
#       'hooks_url': 'https://api.github.com/repos/kkpan11/gtk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kkpan11/gtk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kkpan11/gtk/events',
#       'assignees_url': 'https://api.github.com/repos/kkpan11/gtk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kkpan11/gtk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kkpan11/gtk/tags',
#       'blobs_url': 'https://api.github.com/repos/kkpan11/gtk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kkpan11/gtk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kkpan11/gtk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kkpan11/gtk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kkpan11/gtk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kkpan11/gtk/languages',
#       'stargazers_url': 'https://api.github.com/repos/kkpan11/gtk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kkpan11/gtk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kkpan11/gtk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kkpan11/gtk/subscription',
#       'commits_url': 'https://api.github.com/repos/kkpan11/gtk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kkpan11/gtk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kkpan11/gtk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kkpan11/gtk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kkpan11/gtk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kkpan11/gtk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kkpan11/gtk/merges',
#       'archive_url': 'https://api.github.com/repos/kkpan11/gtk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kkpan11/gtk/downloads',
#       'issues_url': 'https://api.github.com/repos/kkpan11/gtk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kkpan11/gtk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kkpan11/gtk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kkpan11/gtk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kkpan11/gtk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kkpan11/gtk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kkpan11/gtk/deployments',
#       'created_at': '2023-08-01T10:18:03Z',
#       'updated_at': '2025-03-08T16:55:12Z',
#       'pushed_at': '2025-03-08T16:55:07Z',
#       'git_url': 'git://github.com/kkpan11/gtk.git',
#       'ssh_url': 'git@github.com:kkpan11/gtk.git',
#       'clone_url': 'https://github.com/kkpan11/gtk.git',
#       'svn_url': 'https://github.com/kkpan11/gtk',
#       'homepage': 'https://gitlab.gnome.org/GNOME/gtk',
#       'size': 486369,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kkpan11/gtk/pulls/514'},
#      'html': {'href': 'https://github.com/kkpan11/gtk/pull/514'},
#      'issue': {'href': 'https://api.github.com/repos/kkpan11/gtk/issues/514'},
#      'comments': {'href': 'https://api.github.com/repos/kkpan11/gtk/issues/514/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kkpan11/gtk/pulls/514/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kkpan11/gtk/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kkpan11/gtk/pulls/514/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kkpan11/gtk/statuses/e506673aed9fbdbdea8fb73beeb8ffa796f8fbc9'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 64,
#     'deletions': 49,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963914',
#   'type': 'PushEvent',
#   'actor': {'id': 115138590,
#    'login': 'hotspotlab',
#    'display_login': 'hotspotlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hotspotlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115138590?'},
#   'repo': {'id': 941522870,
#    'name': 'hotspotlab/hourly',
#    'url': 'https://api.github.com/repos/hotspotlab/hourly'},
#   'payload': {'repository_id': 941522870,
#    'push_id': 23061345734,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '857039b629660a5f8d0a20c7c29155875f27f221',
#    'before': '408583753c06380a43740b35397ff3409fb40e4e',
#    'commits': [{'sha': '857039b629660a5f8d0a20c7c29155875f27f221',
#      'author': {'email': '115138590+hotspotlab@users.noreply.github.com',
#       'name': 'hotspotlab'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hotspotlab/hourly/commits/857039b629660a5f8d0a20c7c29155875f27f221'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:06Z'},
#  {'id': '47346963922',
#   'type': 'CreateEvent',
#   'actor': {'id': 135972019,
#    'login': 'MADSHREYASYT',
#    'display_login': 'MADSHREYASYT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MADSHREYASYT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/135972019?'},
#   'repo': {'id': 945211414,
#    'name': 'MADSHREYASYT/IObit_Uninstaller_Pro_Crack',
#    'url': 'https://api.github.com/repos/MADSHREYASYT/IObit_Uninstaller_Pro_Crack'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-03-08T22:55:07Z'},
#  {'id': '47346963910',
#   'type': 'PushEvent',
#   'actor': {'id': 179322580,
#    'login': 'akinyele-insights-bot',
#    'display_login': 'akinyele-insights-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akinyele-insights-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/179322580?'},
#   'repo': {'id': 847016101,
#    'name': 'akinyele-spin/spotify-insights',
#    'url': 'https://api.github.com/repos/akinyele-spin/spotify-insights'},
#   'payload': {'repository_id': 847016101,
#    'push_id': 23061345733,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '05277c058c605a2395f725fb9cd903c1b43108ee',
#    'before': '86788b7dd749b8b422a5bbb6ce63b4faf73e48df',
#    'commits': [{'sha': '05277c058c605a2395f725fb9cd903c1b43108ee',
#      'author': {'email': 'akinyele.insights@gmail.com',
#       'name': 'akinyele-insights-bot'},
#      'message': '[job] Update insights.json\n\nUnix timestamp: 1741474504',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/akinyele-spin/spotify-insights/commits/05277c058c605a2395f725fb9cd903c1b43108ee'}]},
#   'public': True,
#   'created_at': '2025-03-08T22:55:06Z',
#   'org': {'id': 138708904,
#    'login': 'akinyele-spin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/akinyele-spin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138708904?'}}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2025-01-23T06:17:33Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 15,
#   'watchers_count': 15,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 372,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 372,
#   'open_issues': 3,
#   'watchers': 15,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2025-03-03T20:02:49Z',
#   'pushed_at': '2025-02-18T00:05:02Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 539,
#   'stargazers_count': 106,
#   'watchers_count': 106,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 36,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 28,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 36,
#   'open_issues': 28,
#   'watchers': 106,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 26,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 26,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2025-02-21T15:47:57Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1134,
#   'watchers_count': 1134,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1038,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1038,
#   'open_issues': 11,
#   'watchers': 1134,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2025-01-15T02:22:55Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 10,
#   'watchers_count': 10,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 10,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 66,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-10-01T18:04:47Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 40,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 40,
#   'open_issues': 11,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-09-17T15:30:38Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 92,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 92,
#   'open_issues': 37,
#   'watchers': 208,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
access_token = 'seu_token'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2025-01-23T06:17:33Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 15,
#    'watchers_count': 15,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 372,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 372,
#    'open_issues': 3,
#    'watchers': 15,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2025-03-03T20:02:49Z',
#    'pushed_at': '2025-02-18T00:05:02Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 539,
#    'stargazers_count': 106,
#    'watchers_count': 106,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 36,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 28,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 36,
#    'open_issues': 28,
#    'watchers': 106,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 26,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 26,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2025-02-21T15:47:57Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1134,
#    'watchers_count': 1134,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1038,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1038,
#    'open_issues': 11,
#    'watchers': 1134,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2025-01-15T02:22:55Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 10,
#    'watchers_count': 10,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 10,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-09-14T07:43:36Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 93,
#    'watchers_count': 93,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 66,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 66,
#    'open_issues': 14,
#    'watchers': 93,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
# ...
#    'git_refs_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/deployments',
#    'created_at': '2024-11-06T21:23:07Z',
#    'updated_at': '2024-11-22T07:45:08Z',
#    'pushed_at': '2024-11-22T07:35:43Z',
#    'git_url': 'git://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#    'ssh_url': 'git@github.com:amzn/traffic-quality-smart-pixel-loader.git',
#    'clone_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#    'svn_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader',
#    'homepage': None,
#    'size': 14,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'TypeScript',
#    'has_issues': False,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 431462375,
#    'node_id': 'R_kgDOGbeX5w',
#    'name': 'trans-encoder',
#    'full_name': 'amzn/trans-encoder',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/trans-encoder',
#    'description': 'Trans-Encoder: Unsupervised sentence-pair modelling through self- and mutual-distillations',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/trans-encoder',
#    'forks_url': 'https://api.github.com/repos/amzn/trans-encoder/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/trans-encoder/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/trans-encoder/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/trans-encoder/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/trans-encoder/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/trans-encoder/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/trans-encoder/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/trans-encoder/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/trans-encoder/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/trans-encoder/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/trans-encoder/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/trans-encoder/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/trans-encoder/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/trans-encoder/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/trans-encoder/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/trans-encoder/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/trans-encoder/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/trans-encoder/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/trans-encoder/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/trans-encoder/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/trans-encoder/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/trans-encoder/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/trans-encoder/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/trans-encoder/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/trans-encoder/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/trans-encoder/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/trans-encoder/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/trans-encoder/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/trans-encoder/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/trans-encoder/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/trans-encoder/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/trans-encoder/deployments',
#    'created_at': '2021-11-24T11:44:32Z',
#    'updated_at': '2025-01-11T09:08:02Z',
#    'pushed_at': '2024-05-30T18:51:20Z',
#    'git_url': 'git://github.com/amzn/trans-encoder.git',
#    'ssh_url': 'git@github.com:amzn/trans-encoder.git',
#    'clone_url': 'https://github.com/amzn/trans-encoder.git',
#    'svn_url': 'https://github.com/amzn/trans-encoder',
#    'homepage': '',
#    'size': 45,
#    'stargazers_count': 132,
#    'watchers_count': 132,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 3,
#    'watchers': 132,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 638205169,
#    'node_id': 'R_kgDOJgo88Q',
#    'name': 'user-satisfaction-modeling',
#    'full_name': 'amzn/user-satisfaction-modeling',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'description': 'Codebase for the paper "Schema-guided User Satisfaction Modeling for Task-oriented Dialogues"',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling',
#    'forks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/deployments',
#    'created_at': '2023-05-09T09:52:46Z',
#    'updated_at': '2024-10-09T14:18:49Z',
#    'pushed_at': '2024-10-09T14:18:45Z',
#    'git_url': 'git://github.com/amzn/user-satisfaction-modeling.git',
#    'ssh_url': 'git@github.com:amzn/user-satisfaction-modeling.git',
#    'clone_url': 'https://github.com/amzn/user-satisfaction-modeling.git',
#    'svn_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 11,
#    'watchers_count': 11,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 3,
#    'watchers': 11,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2025-01-23T06:17:33Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 15,
#    'watchers_count': 15,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 372,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 372,
#    'open_issues': 3,
#    'watchers': 15,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2025-03-03T20:02:49Z',
#    'pushed_at': '2025-02-18T00:05:02Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 539,
#    'stargazers_count': 106,
#    'watchers_count': 106,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 36,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 28,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 36,
#    'open_issues': 28,
#    'watchers': 106,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 26,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 26,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2025-02-21T15:47:57Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1134,
#    'watchers_count': 1134,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1038,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1038,
#    'open_issues': 11,
#    'watchers': 1134,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2025-01-15T02:22:55Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 10,
#    'watchers_count': 10,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 10,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-09-14T07:43:36Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 93,
#    'watchers_count': 93,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 66,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 66,
#    'open_issues': 14,
#    'watchers': 93,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
# ...
#    'git_refs_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/traffic-quality-smart-pixel-loader/deployments',
#    'created_at': '2024-11-06T21:23:07Z',
#    'updated_at': '2024-11-22T07:45:08Z',
#    'pushed_at': '2024-11-22T07:35:43Z',
#    'git_url': 'git://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#    'ssh_url': 'git@github.com:amzn/traffic-quality-smart-pixel-loader.git',
#    'clone_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader.git',
#    'svn_url': 'https://github.com/amzn/traffic-quality-smart-pixel-loader',
#    'homepage': None,
#    'size': 14,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'TypeScript',
#    'has_issues': False,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 431462375,
#    'node_id': 'R_kgDOGbeX5w',
#    'name': 'trans-encoder',
#    'full_name': 'amzn/trans-encoder',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/trans-encoder',
#    'description': 'Trans-Encoder: Unsupervised sentence-pair modelling through self- and mutual-distillations',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/trans-encoder',
#    'forks_url': 'https://api.github.com/repos/amzn/trans-encoder/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/trans-encoder/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/trans-encoder/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/trans-encoder/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/trans-encoder/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/trans-encoder/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/trans-encoder/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/trans-encoder/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/trans-encoder/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/trans-encoder/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/trans-encoder/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/trans-encoder/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/trans-encoder/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/trans-encoder/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/trans-encoder/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/trans-encoder/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/trans-encoder/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/trans-encoder/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/trans-encoder/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/trans-encoder/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/trans-encoder/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/trans-encoder/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/trans-encoder/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/trans-encoder/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/trans-encoder/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/trans-encoder/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/trans-encoder/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/trans-encoder/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/trans-encoder/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/trans-encoder/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/trans-encoder/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/trans-encoder/deployments',
#    'created_at': '2021-11-24T11:44:32Z',
#    'updated_at': '2025-01-11T09:08:02Z',
#    'pushed_at': '2024-05-30T18:51:20Z',
#    'git_url': 'git://github.com/amzn/trans-encoder.git',
#    'ssh_url': 'git@github.com:amzn/trans-encoder.git',
#    'clone_url': 'https://github.com/amzn/trans-encoder.git',
#    'svn_url': 'https://github.com/amzn/trans-encoder',
#    'homepage': '',
#    'size': 45,
#    'stargazers_count': 132,
#    'watchers_count': 132,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 3,
#    'watchers': 132,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 638205169,
#    'node_id': 'R_kgDOJgo88Q',
#    'name': 'user-satisfaction-modeling',
#    'full_name': 'amzn/user-satisfaction-modeling',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'description': 'Codebase for the paper "Schema-guided User Satisfaction Modeling for Task-oriented Dialogues"',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling',
#    'forks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/deployments',
#    'created_at': '2023-05-09T09:52:46Z',
#    'updated_at': '2024-10-09T14:18:49Z',
#    'pushed_at': '2024-10-09T14:18:45Z',
#    'git_url': 'git://github.com/amzn/user-satisfaction-modeling.git',
#    'ssh_url': 'git@github.com:amzn/user-satisfaction-modeling.git',
#    'clone_url': 'https://github.com/amzn/user-satisfaction-modeling.git',
#    'svn_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 11,
#    'watchers_count': 11,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 3,
#    'watchers': 11,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 150

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'Ruby'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 150

# %%
repos_language
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'C#',
#  'HTML',
#  'Kotlin',
#  None,
#  'TypeScript',
#  'PHP',
#  'PHP',
#  None,
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  None,
#  'Mustache',
#  'PHP',
#  'Java',
#  'PHP',
#  'Python',
#  'Swift',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Python',
#  'Python']

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                          repository_name          language
# 0                                .github              None
# 1                ads-advanced-tools-docs  Jupyter Notebook
# 2            ads-pao-amznjs-gtm-template            Smarty
# 3                             alexa-coho        JavaScript
# 4                    alexa-skills-kit-js              None
# ..                                   ...               ...
# 145  supply-chain-simulation-environment            Python
# 146           tiny-attribution-generator        TypeScript
# 147   traffic-quality-smart-pixel-loader        TypeScript
# 148                        trans-encoder            Python
# 149           user-satisfaction-modeling            Python
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# ### Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# ### Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'jaoAprendiz'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/jaoAprendiz/linguagens-utilizadas/contents/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201
